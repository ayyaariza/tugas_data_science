# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load The Data

data = pd.read_csv('food_delivery_datasets.csv')
data
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
#cek tipe data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076 entries, 0 to 1075
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        1076 non-null   object
#  1   voucher_amount  1076 non-null   int64
#  2   date_time       1076 non-null   object
#  3   eta_seconds     1076 non-null   int64
#  4   food_price      1076 non-null   int64
#  5   cust_id         1076 non-null   int64
#  6   rating          598 non-null    float64
#  7   delivery_fee    1076 non-null   int64
#  8   resto_id        1076 non-null   int64
#  9   status          1076 non-null   object
#  10  random_id       1076 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 92.6+ KB

# %%
#mengurutkan data berdasarkan food_price termurah hingga termahal

data1 = data.sort_values(by='food_price', ascending=True)
data1
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 202   FOOD-10654               0  2018-09-01T17:22:30.082466         1701
# 412   FOOD-10898               0  2018-09-18T13:59:20.321082         1228
# 858   FOOD-10395               0  2018-08-07T14:52:58.764328          836
# 851   FOOD-11013               0  2018-09-25T18:40:28.904590         1552
# 864   FOOD-10439               0  2018-08-11T20:16:56.407026          652
# ...          ...             ...                         ...          ...
# 1037  FOOD-10781               0  2018-09-12T17:37:10.213124         2528
# 827   FOOD-10565               0  2018-08-24T12:13:00.042608         1936
# 67    FOOD-10633               0  2018-08-31T11:47:18.090120         2474
# 10    FOOD-10386               0  2018-08-06T14:57:55.985171         2673
# 128   FOOD-10212               0  2018-07-21T18:55:34.457186         2723
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
#akan ditampilkan 5 harga makanan termurah

data1[0:5]
# Out:
#        order_id  voucher_amount                   date_time  eta_seconds  \
# 202  FOOD-10654               0  2018-09-01T17:22:30.082466         1701
# 412  FOOD-10898               0  2018-09-18T13:59:20.321082         1228
# 858  FOOD-10395               0  2018-08-07T14:52:58.764328          836
# 851  FOOD-11013               0  2018-09-25T18:40:28.904590         1552
# 864  FOOD-10439               0  2018-08-11T20:16:56.407026          652
#
#      food_price  cust_id  rating  delivery_fee   resto_id     status  \
# 202       12900  1284060     5.0          9000  742624235  Completed
# 412       14200   588886     5.0          4000  742548078  Completed
# 858       15200   472466     5.0          9000  742603023  Completed
# 851       15700   293834     NaN          2000  742807054  Completed
# 864       16000   228764     NaN          9000  742706753  Completed
#
#      random_id
# 202   0.716985
# 412   0.751653
# 858   0.093072
# 851   0.753612
# 864   0.815192

# %%
#mengurutkan data berdasarkan delivery_fee termahal hingga termurah

data2 = data.sort_values(by='delivery_fee', ascending=False)
data2
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 1032  FOOD-10382               0  2018-08-05T22:18:54.638622         2887
# 374   FOOD-10845               0  2018-09-16T11:52:48.597895           45
# 731   FOOD-10381               0  2018-08-05T22:15:05.095392          215
# 257   FOOD-10460               0  2018-08-13T14:48:23.789972         5527
# 373   FOOD-10380               0  2018-08-05T22:08:25.424821          375
# ...          ...             ...                         ...          ...
# 627   FOOD-10936            5000  2018-09-21T14:16:22.702749          399
# 607   FOOD-10766            4000  2018-09-10T21:46:33.787477         2664
# 377   FOOD-11019            2000  2018-09-26T15:26:38.364281         2000
# 378   FOOD-10498            5000  2018-08-18T12:34:23.770540         1978
# 538   FOOD-10219            5000  2018-07-22T10:13:46.317499         1409
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
#akan ditampilkan delivery_fee paling mahal

data2[0:1]
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 1032  FOOD-10382               0  2018-08-05T22:18:54.638622         2887
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# 1032      141400  1383625     NaN         44000  200003382  Completed
#
#       random_id
# 1032   0.138681

# %%
status_order = data["status"]
status_order
# Out:
# 0       Completed
# 1       Completed
# 2       Completed
# 3       Completed
# 4       Completed
#           ...
# 1071    Completed
# 1072    Completed
# 1073    Completed
# 1074    Completed
# 1075    Completed
# Name: status, Length: 1076, dtype: object

# %%
#banyaknya orderan

len(status_order)
# Out:
# 1076

# %%
#banyaknya orderan yang cancelled dan completed

pd.DataFrame(data.groupby(['status'])['status'].size())
# Out:
#            status
# status
# Cancelled     195
# Completed     881
